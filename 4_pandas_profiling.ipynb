# %%
import pandas as pd

# %%
df=pd.read_csv('tested.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
# !pip install pandas-profiling
# Out:
# Collecting pandas-profiling
#   Using cached pandas_profiling-3.2.0-py2.py3-none-any.whl.metadata (21 kB)
# Collecting joblib~=1.1.0 (from pandas-profiling)
#   Using cached joblib-1.1.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting scipy>=1.4.1 (from pandas-profiling)
#   Using cached scipy-1.16.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\users\harry\appdata\local\programs\python\python313\lib\site-packages (from pandas-profiling) (2.3.1)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\harry\appdata\local\programs\python\python313\lib\site-packages (from pandas-profiling) (3.10.5)
# Requirement already satisfied: pydantic>=1.8.1 in c:\users\harry\appdata\local\programs\python\python313\lib\site-packages (from pandas-profiling) (2.11.7)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\harry\appdata\local\programs\python\python313\lib\site-packages (from pandas-profiling) (6.0.2)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\harry\appdata\local\programs\python\python313\lib\site-packages (from pandas-profiling) (3.1.6)
# Collecting markupsafe~=2.1.1 (from pandas-profiling)
#   Using cached MarkupSafe-2.1.5.tar.gz (19 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting visions==0.7.4 (from visions[type_image_path]==0.7.4->pandas-profiling)
#   Using cached visions-0.7.4-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\harry\appdata\local\programs\python\python313\lib\site-packages (from pandas-profiling) (2.3.1)
# Collecting htmlmin>=0.1.12 (from pandas-profiling)
#   Using cached htmlmin-0.1.12.tar.gz (19 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   Getting requirements to build wheel did not run successfully.
#   exit code: 1
#
#   [27 lines of output]
#   Traceback (most recent call last):
#     File "C:\Users\harry\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 389, in <module>
#       main()
#       ~~~~^^
#     File "C:\Users\harry\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 373, in main
#       json_out["return_val"] = hook(**hook_input["kwargs"])
#                                ~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\harry\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 143, in get_requires_for_build_wheel
#       return hook(config_settings)
#     File "C:\Users\harry\AppData\Local\Temp\pip-build-env-drbikky8\overlay\Lib\site-packages\setuptools\build_meta.py", line 331, in get_requires_for_build_wheel
#       return self._get_build_requires(config_settings, requirements=[])
#              ~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\harry\AppData\Local\Temp\pip-build-env-drbikky8\overlay\Lib\site-packages\setuptools\build_meta.py", line 301, in _get_build_requires
#       self.run_setup()
#       ~~~~~~~~~~~~~~^^
#     File "C:\Users\harry\AppData\Local\Temp\pip-build-env-drbikky8\overlay\Lib\site-packages\setuptools\build_meta.py", line 512, in run_setup
#       super().run_setup(setup_script=setup_script)
#       ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\harry\AppData\Local\Temp\pip-build-env-drbikky8\overlay\Lib\site-packages\setuptools\build_meta.py", line 317, in run_setup
#       exec(code, locals())
#       ~~~~^^^^^^^^^^^^^^^^
#     File "<string>", line 4, in <module>
#     File "C:\Users\harry\AppData\Local\Temp\pip-install-djla4b6_\htmlmin_baa8b0dcce0b4b00b749485ce117486f\htmlmin\__init__.py", line 28, in <module>
#       from .main import minify, Minifier
#     File "C:\Users\harry\AppData\Local\Temp\pip-install-djla4b6_\htmlmin_baa8b0dcce0b4b00b749485ce117486f\htmlmin\main.py", line 28, in <module>
#       import cgi
#   ModuleNotFoundError: No module named 'cgi'
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# error: subprocess-exited-with-error
#
# Getting requirements to build wheel did not run successfully.
# exit code: 1
#
# See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
from panda_profiling import ProfileReport
prof=ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from panda_profiling import ProfileReport
#       2 prof=ProfileReport(df)
#       3 prof.to_file(output_file='output.html')
#
# ModuleNotFoundError: No module named 'panda_profiling'
